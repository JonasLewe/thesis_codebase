# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python3 '/content/drive/My Drive/LMU/Master/WS_2122/Masterarbeit/thesis_codebase/Code/src/main.py'
# Out:
# Traceback (most recent call last):
#   File "/content/drive/My Drive/LMU/Master/WS_2122/Masterarbeit/thesis_codebase/Code/src/main.py", line 24, in <module>
#     with open(os.path.join(ROOT_DIR, CONFIG, args.config), "rb") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '../../Config/user_config.yml'
